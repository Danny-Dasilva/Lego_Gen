    "50861",
    "7b",
    "3836",
    "15209",
    "85941",
    "6239",
    "32555",
    "92738",
    "32324",
    "50862",
    "32005a",
    "60603",
    "63082",
    "57585",
    "30359b",
    "32200",
    "6233",
    "72454",
    "3861b",
    "458",
    "4034",
    "3044c",
    "3009a",
    "24375",
    "59230",
    "4166",
    "33085",
    "3437pr0067",
    "3835",
    "6254",
    "18976",
    "33051",
    "14720",
    "2452",
    "3081bc01",
    "92851",
    "9244",
    "44300",
    "30173b",
    "25893",
    "3228a",
    "6256",
    "10884",
    "98721",
    "33303",
    "6192",
    "85975",
    "98834",
    "3963",
    "4863",
    "33172",
    "33286",
    "4285b",
    "92220",
    "30043",
]

# %%
import requests
import json




key = "c1f77b4bef5b5240dc9d07e5bd719a47"


def process_list(my_list):
    query_params = ",".join(k for k in my_list)
    print(query_params)
    url = f"https://rebrickable.com/api/v3/lego/parts/?part_nums={query_params}"

    response = requests.get(url, headers={'Authorization': 'key c1f77b4bef5b5240dc9d07e5bd719a47'})
    return response.json()

# %%
#Loop through 100 at a time
all_parts = []
for i in range(0, len(partlist), 100):
    # output = process_list(partlist[i:i+100])
    print(i, i+100, len(output))
    output = process_list(partlist[0:0+100])
    print(output, len(output))
    break
# Out:
# 0 100 4
# {'count': 189, 'next': 'https://rebrickable.com/api/v3/lego/colors/?key=c1f77b4bef5b5240dc9d07e5bd719a47&page=2&part_nums=3023%2C6141%2C3004%2C3024%2C2780%2C3005%2C3003%2C3710%2C3010%2C3020%2C3069b%2C54200%2C3001%2C3022%2C98138%2C3021%2C2412b%2C3666%2C3062b%2C6558%2C3070b%2C3623%2C3622%2C3009%2C2431%2C3040b%2C3068b%2C4274%2C3795%2C3437%2C2420%2C43093%2C3002%2C32062%2C3713%2C3039%2C4070%2C3460%2C3660%2C6636%2C15573%2C4032a%2C3665%2C85984%2C3700%2C3034%2C3941%2C2357%2C4519%2C11477%2C59900%2C3008%2C87079%2C25269%2C32123b%2C3673%2C4162%2C87580%2C2877%2C87087%2C32054%2C15068%2C30136%2C32028%2C6091%2C4477%2C3001a%2C3749%2C3794a%2C3705%2C2654%2C6536%2C85861%2C63864%2C3011%2C4286%2C44728%2C3003a%2C2540%2C3031%2C59443%2C3065%2C6541%2C2456%2C3032%2C15712%2C99780%2C3701%2C3037%2C60478%2C3832%2C99207%2C50950%2C32013%2C48336%2C3298%2C33291%2C24866%2C4740%2C3794b', 'previous': None, 'results': [{'id': -1, 'name': '[Unknown]', 'rgb': '0033B2', 'is_trans': False, 'external_ids': {'BrickOwl': {'ext_ids': [0, 28, 29, 30, 31, 32, 33, 34, 60, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 156, 157, 158, 160, 162, 163, 169], 'ext_descrs': [['Not Applicable'], ['Modulex Medium Stone Gray'], ['Modulex Charcoal Gray'], ['Modulex Orange'], ['Modulex Ochre Yellow'], ['Modulex Olive Green'], ['Modulex Pastel Green'], ['Modulex Tile Blue'], ['Fabuland Orange'], ['Modulex Aqua Green'], ['Modulex Black'], ['Modulex Brown'], ['Modulex Buff'], ['Modulex Clear'], ['Modulex Lemon'], ['Modulex Light Gray'], ['Modulex Light Orange'], ['Modulex Light Yellow'], ['Modulex Medium Blue'], ['Modulex Pastel Blue'], ['Modulex Pink'], ['Modulex Pink Red'], ['Modulex Red'], ['Modulex Teal Blue'], ['Modulex Terracotta'], ['Modulex Tile Brown'], ['Modulex Tile Gray'], ['Modulex Violet'], ['Modulex White'], ['Warm Yellowish Orange'], ['Medium Yellowish Orange'], ['Reddish Orange'], ['Dark Nougat'], ['Transparent Fire Yellow'], ['Transparent Light Royal Blue'], ['Curry']]}, 'LEGO': {'ext_ids': [16, 125, 158, 176, 178, 180], 'ext_descrs': [['Pink'], ['Light Orange'], ['Tr. Flu. Red'], ['Red Flip/Flop'], ['Yellow Flip/Flop'], ['Curry']]}, 'Peeron': {'ext_ids': [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None], 'ext_descrs': [['blackgoldglitter'], ['curry'], ['dknougat'], ['ffred'], ['ffyellow'], ['fabulime'], ['fabuorange'], ['metalliccopper'], ['metallicwhite'], ['neonblue'], ['pearlgreen'], ['pearlescentpink'], ['redpink'], ['trltgreen'], ['trsalmon']]}, 'LDraw': {'ext_ids': [16, 24, 65, 66, 67, 273, 324, 375, 406, 449, 490, 493, 494, 495, 496, 504, 511], 'ext_descrs': [['Main_Colour'], ['Edge_Colour'], ['Rubber_Yellow'], ['Rubber_Trans_Yellow'], ['Rubber_Trans_Clear'], ['Rubber_Blue'], ['Rubber_Red'], ['Rubber_Light_Gray'], ['Rubber_Dark_Blue'], ['Rubber_Purple'], ['Rubber_Lime'], ['Magnet'], ['Electric_Contact_Alloy'], ['Electric_Contact_Copper'], ['Rubber_Light_Bluish_Gray'], ['Rubber_Flat_Silver'], ['Rubber_White']]}}}, {'id': 0, 'name': 'Black', 'rgb': '05131D', 'is_trans': False, 'external_ids': {'LDraw': {'ext_ids': [256, 0], 'ext_descrs': [['Rubber_Black'], ['Black']]}, 'BrickLink': {'ext_ids': [11], 'ext_descrs': [['Black']]}, 'BrickOwl': {'ext_ids': [38], 'ext_descrs': [['Black']]}, 'LEGO': {'ext_ids': [26, 149, 1012], 'ext_descrs': [['Black', 'BLACK'], ['Metallic Black', 'MET.BLACK'], ['CONDUCT. BLACK']]}, 'Peeron': {'ext_ids': [None], 'ext_descrs': [['black']]}}}, {'id': 1, 'name': 'Blue', 'rgb': '0055BF', 'is_trans': False, 'external_ids': {'BrickLink': {'ext_ids': [7], 'ext_descrs': [['Blue']]}, 'BrickOwl': {'ext_ids': [39], 'ext_descrs': [['Blue']]}, 'LEGO': {'ext_ids': [23, 185], 'ext_descrs': [['Bright Blue', 'BR.BLUE'], ['Metallic Bright Blue', 'MET. BR. BLUE']]}, 'Peeron': {'ext_ids': [None], 'ext_descrs': [['blue']]}, 'LDraw': {'ext_ids': [1], 'ext_descrs': [['Blue']]}}}, {'id': 2, 'name': 'Green', 'rgb': '237841', 'is_trans': False, 'external_ids': {'BrickLink':  ...

# %%
output = process_list(partlist[0:0+50])
# Out:
# 3023,6141,3004,3024,2780,3005,3003,3710,3010,3020,3069b,54200,3001,3022,98138,3021,2412b,3666,3062b,6558,3070b,3623,3622,3009,2431,3040b,3068b,4274,3795,3437,2420,43093,3002,32062,3713,3039,4070,3460,3660,6636,15573,4032a,3665,85984,3700,3034,3941,2357,4519,11477

# %%
output["results"]
# Out:
# {'count': 50,
#  'next': None,
#  'previous': None,
#  'results': [{'external_ids': {'BrickOwl': ['910030'],
#     'Brickset': ['11477', '17134'],
#     'LEGO': ['11477', '17134']},
#    'name': 'Slope Curved 2 x 1 No Studs [1/2 Bow]',
#    'part_cat_id': 37,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/6047276.jpg',
#    'part_num': '11477',
#    'part_url': 'https://rebrickable.com/parts/11477/slope-curved-2-x-1-no-studs-12-bow/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['893367'],
#     'Brickset': ['15573'],
#     'LEGO': ['15573']},
#    'name': 'Plate Special 1 x 2 with 1 Stud with Groove and Inside Stud Holder (Jumper)',
#    'part_cat_id': 9,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/6066097.jpg',
#    'part_num': '15573',
#    'part_url': 'https://rebrickable.com/parts/15573/plate-special-1-x-2-with-1-stud-with-groove-and-inside-stud-holder-jumper/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['682375'],
#     'Brickset': ['2357'],
#     'LEGO': ['2357']},
#    'name': 'Brick 2 x 2 Corner',
#    'part_cat_id': 11,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/4211109.jpg',
#    'part_num': '2357',
#    'part_url': 'https://rebrickable.com/parts/2357/brick-2-x-2-corner/',
#    'print_of': None},
#   {'external_ids': {'BrickLink': ['2412b'],
#     'BrickOwl': ['363948'],
#     'Brickset': ['15561', '2412', '30244', '35248', '51815', '71957'],
#     'LDraw': ['2412b', '30244'],
#     'LEGO': ['15561', '2412', '30244', '35248', '51815', '71957']},
#    'name': 'Tile Special 1 x 2 Grille with Bottom Groove',
#    'part_cat_id': 15,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/241226.jpg',
#    'part_num': '2412b',
#    'part_url': 'https://rebrickable.com/parts/2412b/tile-special-1-x-2-grille-with-bottom-groove/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['45054'],
#     'Brickset': ['2420', '63325'],
#     'LDraw': ['2420', '63325'],
#     'LEGO': ['2420', '63325']},
#    'name': 'Plate 2 x 2 Corner',
#    'part_cat_id': 14,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/242026.jpg',
#    'part_num': '2420',
#    'part_url': 'https://rebrickable.com/parts/2420/plate-2-x-2-corner/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['853045'],
#     'Brickset': ['2431', '35371', '75703', '91143'],
#     'LEGO': ['2431', '35371', '75703', '91143'],
#     'Peeron': ['2431b']},
#    'name': 'Tile 1 x 4 with Groove',
#    'part_cat_id': 19,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/243126.jpg',
#    'part_num': '2431',
#    'part_url': 'https://rebrickable.com/parts/2431/tile-1-x-4-with-groove/',
#    'print_of': None},
#   {'external_ids': {'BrickLink': ['2780'],
#     'BrickOwl': ['33899'],
#     'Brickset': ['2780'],
#     'LEGO': ['2780']},
#    'name': 'Technic Pin with Friction Ridges Lengthwise and Center Slots',
#    'part_cat_id': 53,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/4121715.jpg',
#    'part_num': '2780',
#    'part_url': 'https://rebrickable.com/parts/2780/technic-pin-with-friction-ridges-lengthwise-and-center-slots/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['771344'],
#     'Brickset': ['15589', '3001', '54534', '72841'],
#     'LEGO': ['15589', '3001', '54534', '72841']},
#    'name': 'Brick 2 x 4',
#    'part_cat_id': 11,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/300121.jpg',
#    'part_num': '3001',
#    'part_url': 'https://rebrickable.com/parts/3001/brick-2-x-4/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['462227'],
#     'Brickset': ['3002'],
#     'LEGO': ['3002']},
#    'name': 'Brick 2 x 3',
#    'part_cat_id': 11,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/300201.jpg',
#    'part_num': '3002',
#    'part_url': 'https://rebrickable.com/parts/3002/brick-2-x-3/',
#    'print_of': None},
#   {'external_ids': {'BrickLink': ['3003'],
#     'BrickOwl': ['3003', '939628'],
#     'Brickset': ['15591', '3003', '62404'],
#     'LDraw': ['3003'],
#     'LEGO': ['15591', '3003', '62404']},
#    'name': 'Brick 2 x 2',
#    'part_cat_id': 11,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/300301.jpg',
#    'part_num': '3003',
#    'part_url': 'https://rebrickable.com/parts/3003/brick-2-x-2/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['442413'],
#     'Brickset': ['3004', '93792'],
#     'LDraw': ['3004', '93792'],
#     'LEGO': ['3004', '93792']},
#    'name': 'Brick 1 x 2',
#    'part_cat_id': 11,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/300401.jpg',
#    'part_num': '3004',
#    'part_url': 'https://rebrickable.com/parts/3004/brick-1-x-2/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['656416'],
#     'Brickset': ['3005', '30071', '35382'],
#     'LDraw': ['3005', '30071'],
#     'LEGO': ['3005', '30071', '35382']},
#    'name': 'Brick 1 x 1',
#    'part_cat_id': 11,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/300501.jpg',
#    'part_num': '3005',
#    'part_url': 'https://rebrickable.com/parts/3005/brick-1-x-1/',
#    'print_of': None},
#   {'external_ids': {'BrickLink': ['3009'],
#     'BrickOwl': ['340943'],
#     'Brickset': ['3009'],
#     'LEGO': ['3009']},
#    'name': 'Brick 1 x 6',
#    'part_cat_id': 11,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/300901.jpg',
#    'part_num': '3009',
#    'part_url': 'https://rebrickable.com/parts/3009/brick-1-x-6/',
#    'print_of': None},
#   {'external_ids': {'BrickLink': ['3010'],
#     'BrickOwl': ['752369'],
#     'Brickset': ['3010'],
#     'LEGO': ['3010']},
#    'name': 'Brick 1 x 4',
#    'part_cat_id': 11,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/301001.jpg',
#    'part_num': '3010',
#    'part_url': 'https://rebrickable.com/parts/3010/brick-1-x-4/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['80025'],
#     'Brickset': ['3020'],
#     'LEGO': ['3020']},
#    'name': 'Plate 2 x 4',
#    'part_cat_id': 14,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/302026.jpg',
#    'part_num': '3020',
#    'part_url': 'https://rebrickable.com/parts/3020/plate-2-x-4/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['960521'],
#     'Brickset': ['3021'],
#     'LEGO': ['3021']},
#    'name': 'Plate 2 x 3',
#    'part_cat_id': 14,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/302126.jpg',
#    'part_num': '3021',
#    'part_url': 'https://rebrickable.com/parts/3021/plate-2-x-3/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['566026'],
#     'Brickset': ['3022', '94148'],
#     'LDraw': ['3022', '94148'],
#     'LEGO': ['3022', '94148']},
#    'name': 'Plate 2 x 2',
#    'part_cat_id': 14,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/302226.jpg',
#    'part_num': '3022',
#    'part_url': 'https://rebrickable.com/parts/3022/plate-2-x-2/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['44980'],
#     'Brickset': ['28653', '3023', '6225'],
#     'LDraw': ['28653', '3023'],
#     'LEGO': ['28653', '3023', '6225']},
#    'name': 'Plate 1 x 2',
#    'part_cat_id': 14,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/302326.jpg',
#    'part_num': '3023',
#    'part_url': 'https://rebrickable.com/parts/3023/plate-1-x-2/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['322944'],
#     'Brickset': ['28554', '30008', '3024', '63326'],
#     'LEGO': ['28554', '30008', '3024', '63326'],
#     'Peeron': ['30008']},
#    'name': 'Plate 1 x 1',
#    'part_cat_id': 14,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/302401.jpg',
#    'part_num': '3024',
#    'part_url': 'https://rebrickable.com/parts/3024/plate-1-x-1/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['165861'],
#     'Brickset': ['3034'],
#     'LEGO': ['3034']},
#    'name': 'Plate 2 x 8',
#    'part_cat_id': 14,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/303426.jpg',
#    'part_num': '3034',
#    'part_url': 'https://rebrickable.com/parts/3034/plate-2-x-8/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['822931'],
#     'Brickset': ['3039', '35277', '6227', '63341'],
#     'LEGO': ['3039', '35277', '6227', '63341']},
#    'name': 'Slope 45° 2 x 2',
#    'part_cat_id': 3,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/303921.jpg',
#    'part_num': '3039',
#    'part_url': 'https://rebrickable.com/parts/3039/slope-45-2-x-2/',
#    'print_of': None},
#   {'external_ids': {'BrickLink': ['3040'],
#     'BrickOwl': ['735007'],
#     'Brickset': ['3040', '35281', '6270'],
#     'LDraw': ['3040b'],
#     'LEGO': ['3040', '35281', '6270']},
#    'name': 'Slope 45° 2 x 1 with Bottom Pin',
#    'part_cat_id': 3,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/304026.jpg',
#    'part_num': '3040b',
#    'part_url': 'https://rebrickable.com/parts/3040b/slope-45-2-x-1-with-bottom-pin/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['763649'],
#     'Brickset': ['18860', '30068', '3062', '35390'],
#     'LDraw': ['30068', '3062b'],
#     'LEGO': ['18860', '30068', '3062', '35390']},
#    'name': 'Brick Round 1 x 1 Open Stud',
#    'part_cat_id': 20,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/306201.jpg',
#    'part_num': '3062b',
#    'part_url': 'https://rebrickable.com/parts/3062b/brick-round-1-x-1-open-stud/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['462122'],
#     'Brickset': ['3068', '63327'],
#     'LEGO': ['3068', '63327']},
#    'name': 'Tile 2 x 2 with Groove',
#    'part_cat_id': 19,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/306826.jpg',
#    'part_num': '3068b',
#    'part_url': 'https://rebrickable.com/parts/3068b/tile-2-x-2-with-groove/',
#    'print_of': None},
#   {'external_ids': {'BrickLink': ['3069b'],
#     'BrickOwl': ['487300'],
#     'Brickset': ['15598',
#      '30070',
#      '3069',
#      '30695',
#      '35386',
#      '37293',
#      '45880',
#      '54285',
#      '59489',
#      '63286'],
#     'LEGO': ['15598',
#      '30070',
#      '3069',
#      '30695',
#      '35386',
#      '37293',
#      '45880',
#      '54285',
#      '59489',
#      '63286']},
#    'name': 'Tile 1 x 2 with Groove',
#    'part_cat_id': 19,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/306901.jpg',
#    'part_num': '3069b',
#    'part_url': 'https://rebrickable.com/parts/3069b/tile-1-x-2-with-groove/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['55275'],
#     'Brickset': ['30039', '3070', '3070b', '35403', '39727', '53836'],
#     'LEGO': ['30039', '3070', '35403', '39727', '53836']},
#    'name': 'Tile 1 x 1 with Groove',
#    'part_cat_id': 19,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/307001.jpg',
#    'part_num': '3070b',
#    'part_url': 'https://rebrickable.com/parts/3070b/tile-1-x-1-with-groove/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['515411'],
#     'Brickset': ['32062'],
#     'LEGO': ['32062'],
#     'Peeron': ['3704a']},
#    'name': 'Technic Axle 2 Notched',
#    'part_cat_id': 46,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/4142865.jpg',
#    'part_num': '32062',
#    'part_url': 'https://rebrickable.com/parts/32062/technic-axle-2-notched/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['719240'],
#     'Brickset': ['17556', '20678', '31460', '3437', '34575', '89461', '89462'],
#     'LDraw': ['31460', '3437'],
#     'LEGO': ['17556', '20678', '31460', '3437', '34575', '89461', '89462']},
#    'name': 'Duplo Brick 2 x 2',
#    'part_cat_id': 4,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/343721.jpg',
#    'part_num': '3437',
#    'part_url': 'https://rebrickable.com/parts/3437/duplo-brick-2-x-2/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['840367'],
#     'Brickset': ['3460'],
#     'LEGO': ['3460']},
#    'name': 'Plate 1 x 8',
#    'part_cat_id': 14,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/346026.jpg',
#    'part_num': '3460',
#    'part_url': 'https://rebrickable.com/parts/3460/plate-1-x-8/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['367537'],
#     'Brickset': ['3622', '45505'],
#     'LDraw': ['3622', '45505'],
#     'LEGO': ['3622', '45505']},
#    'name': 'Brick 1 x 3',
#    'part_cat_id': 11,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/362201.jpg',
#    'part_num': '3622',
#    'part_url': 'https://rebrickable.com/parts/3622/brick-1-x-3/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['212990'],
#     'Brickset': ['3623'],
#     'LEGO': ['3623']},
#    'name': 'Plate 1 x 3',
#    'part_cat_id': 14,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/362326.jpg',
#    'part_num': '3623',
#    'part_url': 'https://rebrickable.com/parts/3623/plate-1-x-3/',
#    'print_of': None},
#   {'external_ids': {'BrickLink': ['3660'],
#     'BrickOwl': ['384426'],
#     'Brickset': ['3660', '76959'],
#     'LDraw': ['3660b'],
#     'LEGO': ['3660', '76959']},
#    'name': 'Slope Inverted 45° 2 x 2 [Ovoid Bottom Pin, Bar-sized Stud Holes]',
#    'part_cat_id': 3,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/366026.jpg',
#    'part_num': '3660',
#    'part_url': 'https://rebrickable.com/parts/3660/slope-inverted-45-2-x-2-ovoid-bottom-pin-bar-sized-stud-holes/',
#    'print_of': None},
#   {'external_ids': {'BrickLink': ['3665'],
#     'BrickOwl': ['320373'],
#     'Brickset': ['3665'],
#     'LDraw': ['3665a', '3665b'],
#     'LEGO': ['3665']},
#    'name': 'Slope Inverted 45° 2 x 1',
#    'part_cat_id': 3,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/366526.jpg',
#    'part_num': '3665',
#    'part_url': 'https://rebrickable.com/parts/3665/slope-inverted-45-2-x-1/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['804561'],
#     'Brickset': ['3666'],
#     'LEGO': ['3666']},
#    'name': 'Plate 1 x 6',
#    'part_cat_id': 14,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/366626.jpg',
#    'part_num': '3666',
#    'part_url': 'https://rebrickable.com/parts/3666/plate-1-x-6/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['64503'],
#     'Brickset': ['3700'],
#     'LEGO': ['3700']},
#    'name': 'Technic Brick 1 x 2 [1 Hole]',
#    'part_cat_id': 8,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/370026.jpg',
#    'part_num': '3700',
#    'part_url': 'https://rebrickable.com/parts/3700/technic-brick-1-x-2-1-hole/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['515555'],
#     'Brickset': ['3710'],
#     'LEGO': ['3710']},
#    'name': 'Plate 1 x 4',
#    'part_cat_id': 14,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/371026.jpg',
#    'part_num': '3710',
#    'part_url': 'https://rebrickable.com/parts/3710/plate-1-x-4/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['88261'],
#     'Brickset': ['42798', '6590'],
#     'LEGO': ['42798', '6590'],
#     'Peeron': ['6590']},
#    'name': 'Technic Bush',
#    'part_cat_id': 54,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/4125313.jpg',
#    'part_num': '3713',
#    'part_url': 'https://rebrickable.com/parts/3713/technic-bush/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['735504'],
#     'Brickset': ['3795'],
#     'LEGO': ['3795']},
#    'name': 'Plate 2 x 6',
#    'part_cat_id': 14,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/379526.jpg',
#    'part_num': '3795',
#    'part_url': 'https://rebrickable.com/parts/3795/plate-2-x-6/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['997602'],
#     'Brickset': ['39223', '6116', '6143'],
#     'LDraw': ['3941', '6143'],
#     'LEGO': ['39223', '6116', '6143']},
#    'name': 'Brick Round 2 x 2 with Axle Hole',
#    'part_cat_id': 20,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/614301.jpg',
#    'part_num': '3941',
#    'part_url': 'https://rebrickable.com/parts/3941/brick-round-2-x-2-with-axle-hole/',
#    'print_of': None},
#   {'external_ids': {'BrickLink': ['4032'],
#     'BrickOwl': ['680648'],
#     'Brickset': ['4032'],
#     'LEGO': ['4032'],
#     'Peeron': ['4032']},
#    'name': 'Plate Round 2 x 2 with Axle Hole Type 1 (+ Opening)',
#    'part_cat_id': 21,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/403226.jpg',
#    'part_num': '4032a',
#    'part_url': 'https://rebrickable.com/parts/4032a/plate-round-2-x-2-with-axle-hole-type-1-opening/',
#    'print_of': None},
#   {'external_ids': {'BrickLink': ['4070'],
#     'BrickOwl': ['475629'],
#     'Brickset': ['30069', '35388', '4070'],
#     'LDraw': ['30069', '4070'],
#     'LEGO': ['30069', '35388', '4070']},
#    'name': 'Brick Special 1 x 1 with Headlight and No Slot',
#    'part_cat_id': 5,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/407001.jpg',
#    'part_num': '4070',
#    'part_url': 'https://rebrickable.com/parts/4070/brick-special-1-x-1-with-headlight-and-no-slot/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['778994'],
#     'Brickset': ['4274'],
#     'LEGO': ['4274']},
#    'name': 'Technic Pin 1/2',
#    'part_cat_id': 53,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/4143005.jpg',
#    'part_num': '4274',
#    'part_url': 'https://rebrickable.com/parts/4274/technic-pin-12/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['394212'],
#     'Brickset': ['43093'],
#     'LEGO': ['43093']},
#    'name': 'Technic Axle Pin with Friction Ridges Lengthwise',
#    'part_cat_id': 53,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/4206482.jpg',
#    'part_num': '43093',
#    'part_url': 'https://rebrickable.com/parts/43093/technic-axle-pin-with-friction-ridges-lengthwise/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['151465'],
#     'Brickset': ['4519'],
#     'LEGO': ['4519']},
#    'name': 'Technic Axle 3',
#    'part_cat_id': 46,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/4211815.jpg',
#    'part_num': '4519',
#    'part_url': 'https://rebrickable.com/parts/4519/technic-axle-3/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['158788'],
#     'Brickset': ['18862', '33847', '35338', '50746', '54200', '63290'],
#     'LEGO': ['18862', '33847', '35338', '50746', '54200', '63290']},
#    'name': 'Slope 30° 1 x 1 x 2/3 (Cheese Slope)',
#    'part_cat_id': 3,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/4504382.jpg',
#    'part_num': '54200',
#    'part_url': 'https://rebrickable.com/parts/54200/slope-30-1-x-1-x-23-cheese-slope/',
#    'print_of': None},
#   {'external_ids': {'BrickLink': ['4073'],
#     'BrickOwl': ['961948'],
#     'Brickset': ['15570', '30057', '34823', '39799', '44325', '6141'],
#     'LDraw': ['4073', '6141'],
#     'LEGO': ['15570', '30057', '34823', '39799', '44325', '51809', '6141'],
#     'Peeron': ['4073']},
#    'name': 'Plate Round 1 x 1 with Solid Stud',
#    'part_cat_id': 21,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/614126.jpg',
#    'part_num': '6141',
#    'part_url': 'https://rebrickable.com/parts/6141/plate-round-1-x-1-with-solid-stud/',
#    'print_of': None},
#   {'external_ids': {'BrickLink': ['6558'],
#     'BrickOwl': ['99899'],
#     'Brickset': ['6558'],
#     'LEGO': ['6558']},
#    'name': 'Technic Pin Long with Friction Ridges Lengthwise, 2 Center Slots',
#    'part_cat_id': 53,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/4514553.jpg',
#    'part_num': '6558',
#    'part_url': 'https://rebrickable.com/parts/6558/technic-pin-long-with-friction-ridges-lengthwise-2-center-slots/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['154034'],
#     'Brickset': ['63324', '6636', '75702'],
#     'LEGO': ['63324', '6636', '75702']},
#    'name': 'Tile 1 x 6 with Groove',
#    'part_cat_id': 19,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/4211549.jpg',
#    'part_num': '6636',
#    'part_url': 'https://rebrickable.com/parts/6636/tile-1-x-6-with-groove/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['444606'],
#     'Brickset': ['85984'],
#     'LEGO': ['85984'],
#     'Peeron': ['x1972']},
#    'name': 'Slope 30° 1 x 2 x 2/3',
#    'part_cat_id': 3,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/4548180.jpg',
#    'part_num': '85984',
#    'part_url': 'https://rebrickable.com/parts/85984/slope-30-1-x-2-x-23/',
#    'print_of': None},
#   {'external_ids': {'BrickOwl': ['474589'],
#     'Brickset': ['35380', '35381', '39797', '98138'],
#     'LEGO': ['35380', '35381', '39797', '98138']},
#    'name': 'Tile Round 1 x 1',
#    'part_cat_id': 67,
#    'part_img_url': 'https://cdn.rebrickable.com/media/parts/elements/6139403.jpg',
#    'part_num': '98138',
#    'part_url': 'https://rebrickable.com/parts/98138/tile-round-1-x-1/',
#    'print_of': None}]}

# %%
import json
  
details = {'Name': "Bob",
          'Age' :28}
  
with open('convert.txt', 'w') as convert_file:
     convert_file.write(json.dumps(details))
